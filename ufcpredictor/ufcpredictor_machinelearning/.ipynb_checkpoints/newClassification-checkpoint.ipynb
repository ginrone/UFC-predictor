# %%
import numpy as np
import pandas as pd

df = pd.read_csv('dataScrapped/allFight.csv')

# %%
for column in df:
    df = df[df[column] != '--']

df['Win'] = 1

dfReversed = df.sample(frac = 1,axis=0)

for index, row in df.iterrows():
    df.loc[index,'A_Fighter'], df.loc[index,'B_Fighter'] = df.loc[index,'B_Fighter'], df.loc[index,'A_Fighter']
    df.loc[index,'A_height'], df.loc[index,'B_height'] = df.loc[index,'B_height'], df.loc[index,'A_height']
    df.loc[index,'A_weight'], df.loc[index,'B_weight'] = df.loc[index,'B_weight'], df.loc[index,'A_weight']
    df.loc[index,'A_range'], df.loc[index,'B_range'] = df.loc[index,'B_range'], df.loc[index,'A_range']
    df.loc[index,'A_Stance'], df.loc[index,'B_Stance'] = df.loc[index,'B_Stance'], df.loc[index,'A_Stance']
    df.loc[index,'A_YearBirth'], df.loc[index,'B_YearBirth'] = df.loc[index,'B_YearBirth'], df.loc[index,'A_YearBirth']
    df.loc[index,'A_SigStrikeLanded'], df.loc[index,'B_SigStrikeLanded'] = df.loc[index,'B_SigStrikeLanded'], df.loc[index,'A_SigStrikeLanded']
    df.loc[index,'A_SigStrikeAcc'], df.loc[index,'B_SigStrikeAcc'] = df.loc[index,'B_SigStrikeAcc'], df.loc[index,'A_SigStrikeAcc']
    df.loc[index,'A_SigStrikeAbsorb'], df.loc[index,'B_SigStrikeAbsorb'] = df.loc[index,'B_SigStrikeAbsorb'], df.loc[index,'A_SigStrikeAbsorb']
    df.loc[index,'A_SigStrikeDef'], df.loc[index,'B_SigStrikeDef'] = df.loc[index,'B_SigStrikeDef'], df.loc[index,'A_SigStrikeDef']
    df.loc[index,'A_TakedownAvg'], df.loc[index,'B_TakedownAvg'] = df.loc[index,'B_TakedownAvg'], df.loc[index,'A_TakedownAvg']
    df.loc[index,'A_TakedownAcc'], df.loc[index,'B_TakedownAcc'] = df.loc[index,'B_TakedownAcc'], df.loc[index,'A_TakedownAcc']
    df.loc[index,'A_TakedownDef'], df.loc[index,'B_TakedownDef'] = df.loc[index,'B_TakedownDef'], df.loc[index,'A_TakedownDef']
    df.loc[index,'A_SubAvg'], df.loc[index,'B_SubAvg'] = df.loc[index,'B_SubAvg'], df.loc[index,'A_SubAvg']
    df.loc[index,'Win'] = 0
    
df = pd.concat([df,dfReversed]).sample(frac = 1)

# %%
df.head(10)
# Out:
#                 A_Fighter           B_Fighter           Division   WinBy  \
# 1471          Renan Barao        Mitch Gagnon       Bantamweight     SUB
# 6233       Chan Sung Jung      Yair Rodriguez      Featherweight  KO/TKO
# 4001       Tamdan McCrory        Akihiro Gono       Welterweight     SUB
# 616      Rashid Magomedov      Beneil Dariush        Lightweight   U-DEC
# 988         Diego Brandao        Brian Ortega      Featherweight     SUB
# 4830  Khalil Rountree Jr.  Modestas Bukauskas  Light Heavyweight  KO/TKO
# 6326          Eryk Anders        Tim Williams       Middleweight  KO/TKO
# 3778         Yushin Okami         Dean Lister       Middleweight   U-DEC
# 5091        Carlos Ulberg   Kennedy Nzechukwu  Light Heavyweight  KO/TKO
# 1821           Phil Davis     Anthony Johnson  Light Heavyweight   U-DEC
#
#       EventYear EventLocation A_height A_weight A_range  A_Stance  ...  \
# 1471     2014.0       Barueri     66.0    145.0    70.0  Orthodox  ...
# 6233     2018.0        Denver     67.0    145.0    72.0  Orthodox  ...
# 4001     2007.0        Newark     76.0    185.0    76.0    Switch  ...
# 616      2016.0    MexicoCity     69.0    155.0    70.0  Orthodox  ...
# 988      2016.0      LasVegas     67.0    145.0    64.0  Orthodox  ...
# 4830     2021.0      LasVegas     73.0    205.0    76.0  Southpaw  ...
# 6326     2018.0       Lincoln     73.0    185.0    75.0  Southpaw  ...
# 3778     2008.0      LasVegas     74.0    170.0    75.0  Southpaw  ...
# 5091     2021.0      LasVegas     76.0    205.0    77.0  Orthodox  ...
# 1821     2014.0     Baltimore     74.0    205.0    79.0  Orthodox  ...
#
#      B_YearBirth  B_SigStrikeLanded  B_SigStrikeAcc  B_SigStrikeAbsorb  \
# 1471      1984.0               2.76            46.0               2.21
# 6233      1992.0               4.67            45.0               4.12
# 4001      1974.0               2.18            48.0               2.67
# 616       1989.0               3.81            49.0               2.55
# 988       1991.0               4.19            38.0               6.66
# 4830      1994.0               3.59            37.0               4.54
# 6326      1986.0               3.07            38.0               3.55
# 3778      1976.0               1.26            35.0               1.89
# 5091      1992.0               4.68            44.0               4.36
# 1821      1984.0               3.25            47.0               1.83
#
#       B_SigStrikeDef  B_TakedownAvg  B_TakedownAcc  B_TakedownDef  B_SubAvg  \
# 1471            61.0           1.16           25.0           65.0       1.9
# 6233            53.0           0.83           28.0           62.0       0.7
# 4001            63.0           1.01           84.0           46.0       0.5
# 616             58.0           1.95           34.0           80.0       0.9
# 988             49.0           0.95           23.0           56.0       1.2
# 4830            52.0           0.00            0.0          100.0       0.0
# 6326            48.0           1.81           40.0          100.0       0.0
# 3778            61.0           1.58           15.0           50.0       1.1
# 5091            51.0           0.79           62.0           81.0       0.2
# 1821            60.0           2.43           57.0           77.0       0.6
#
#      Win
# 1471   1
# 6233   0
# 4001   0
# 616    0
# 988    0
# 4830   1
# 6326   1
# 3778   1
# 5091   0
# 1821   0
#
# [10 rows x 33 columns]

# %%
dumDivision = pd.get_dummies(df['Division'],prefix='Div_')
df = pd.concat([df, dumDivision], axis='columns')

# dumWinBy = pd.get_dummies(df['WinBy'],prefix='By_')
# df = pd.concat([df, dumWinBy], axis='columns')

# dumYear = pd.get_dummies(df['EventYear'],prefix='Year_')
# df = pd.concat([df, dumYear], axis='columns')

# dumLocation = pd.get_dummies(df['EventLocation'],prefix='Loc_')
# df = pd.concat([df, dumLocation], axis='columns')

dumAStance = pd.get_dummies(df['A_Stance'],prefix='A_')
df = pd.concat([df, dumAStance], axis='columns')

dumBStance = pd.get_dummies(df['B_Stance'],prefix='B_')
df = pd.concat([df, dumBStance], axis='columns')

# %%
df.head()
# Out:
#              A_Fighter       B_Fighter       Division   WinBy  EventYear  \
# 1471       Renan Barao    Mitch Gagnon   Bantamweight     SUB     2014.0
# 6233    Chan Sung Jung  Yair Rodriguez  Featherweight  KO/TKO     2018.0
# 4001    Tamdan McCrory    Akihiro Gono   Welterweight     SUB     2007.0
# 616   Rashid Magomedov  Beneil Dariush    Lightweight   U-DEC     2016.0
# 988      Diego Brandao    Brian Ortega  Featherweight     SUB     2016.0
#
#      EventLocation A_height A_weight A_range  A_Stance  ...  \
# 1471       Barueri     66.0    145.0    70.0  Orthodox  ...
# 6233        Denver     67.0    145.0    72.0  Orthodox  ...
# 4001        Newark     76.0    185.0    76.0    Switch  ...
# 616     MexicoCity     69.0    155.0    70.0  Orthodox  ...
# 988       LasVegas     67.0    145.0    64.0  Orthodox  ...
#
#      Div__Women's Flyweight  Div__Women's Strawweight  A__OpenStance  \
# 1471                      0                         0              0
# 6233                      0                         0              0
# 4001                      0                         0              0
# 616                       0                         0              0
# 988                       0                         0              0
#
#       A__Orthodox  A__Southpaw  A__Switch  B__OpenStance  B__Orthodox  \
# 1471            1            0          0              0            0
# 6233            1            0          0              0            1
# 4001            0            0          1              0            0
# 616             1            0          0              0            0
# 988             1            0          0              0            0
#
#       B__Southpaw B__Switch
# 1471            1         0
# 6233            0         0
# 4001            0         1
# 616             1         0
# 988             0         1
#
# [5 rows x 54 columns]

# %%
df['Win'].value_counts()
# Out:
# 1    5827
# 0    5827
# Name: Win, dtype: int64

# %%
pct_win = df['Win'].value_counts()/len(df)
pct_win.plot(kind='pie',autopct='%1.1f%%', rot=0)
# Out:
# <AxesSubplot:ylabel='Win'>

# %%
from sklearn.model_selection import train_test_split

X_values = df.drop(['A_Fighter','B_Fighter','Division','WinBy','EventLocation','A_Stance','B_Stance','Win'],axis=1)
y_values = df['Win']

X_train, X_test, y_train, y_test = train_test_split(X_values, y_values, test_size=0.2, random_state=99)

X_values
# Out:
#       EventYear A_height A_weight A_range A_YearBirth  A_SigStrikeLanded  \
# 1471     2014.0     66.0    145.0    70.0      1987.0               3.78
# 6233     2018.0     67.0    145.0    72.0      1987.0               3.97
# 4001     2007.0     76.0    185.0    76.0      1986.0               2.07
# 616      2016.0     69.0    155.0    70.0      1984.0               4.40
# 988      2016.0     67.0    145.0    64.0      1987.0               2.94
# ...         ...      ...      ...     ...         ...                ...
# 6049     2019.0     74.0    205.0    75.0      1989.0               4.53
# 3141     2022.0     70.0    145.0    71.0      1984.0               3.52
# 416      2017.0     68.0    145.0    70.0      1994.0               3.40
# 4956     2021.0     77.0    250.0    77.0      1983.0               3.05
# 975      2016.0     68.0    155.0    69.0      1984.0               3.68
#
#       A_SigStrikeAcc  A_SigStrikeAbsorb  A_SigStrikeDef  A_TakedownAvg  ...  \
# 1471            36.0               3.90            57.0           1.49  ...
# 6233            42.0               4.35            52.0           0.74  ...
# 4001            49.0               1.60            46.0           2.28  ...
# 616             49.0               3.05            54.0           0.67  ...
# 988             47.0               3.38            62.0           3.21  ...
# ...              ...                ...             ...            ...  ...
# 6049            47.0               3.97            55.0           0.47  ...
# 3141            38.0               3.16            51.0           2.76  ...
# 416             42.0               2.25            67.0           1.35  ...
# 4956            39.0               3.33            54.0           0.29  ...
# 975             40.0               4.09            62.0           0.74  ...
#
#       Div__Women's Flyweight  Div__Women's Strawweight  A__OpenStance  \
# 1471                       0                         0              0
# 6233                       0                         0              0
# 4001                       0                         0              0
# 616                        0                         0              0
# 988                        0                         0              0
# ...                      ...                       ...            ...
# 6049                       0                         0              0
# 3141                       0                         0              0
# 416                        0                         0              0
# 4956                       0                         0              0
# 975                        0                         0              0
#
#      A__Orthodox A__Southpaw A__Switch B__OpenStance  B__Orthodox  \
# 1471           1           0         0             0            0
# 6233           1           0         0             0            1
# 4001           0           0         1             0            0
# 616            1           0         0             0            0
# 988            1           0         0             0            0
# ...          ...         ...       ...           ...          ...
# 6049           1           0         0             0            0
# 3141           1           0         0             0            1
# 416            0           1         0             0            0
# 4956           0           1         0             0            1
# 975            1           0         0             0            0
#
#       B__Southpaw  B__Switch
# 1471            1          0
# 6233            0          0
# 4001            0          1
# 616             1          0
# 988             0          1
# ...           ...        ...
# 6049            1          0
# 3141            0          0
# 416             1          0
# 4956            0          0
# 975             1          0
#
# [11654 rows x 46 columns]

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier

randomForest = RandomForestClassifier(random_state=99)
randomForest.fit(X_train,y_train) 

print("Optimal number of features : %d" % randomForest.n_features_)
# Out:
# Optimal number of features : 46
# C:\Users\test\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.feature_selection import RFECV

rfecv_rf = RFECV(estimator=randomForest,cv=5)
rfecv_rf.fit(X_train,y_train) 

print("Optimal number of features : %d" % rfecv_rf.n_features_)
# Out:
# Optimal number of features : 46

# %%
from sklearn.ensemble import BaggingClassifier

rfecv_rfBag = BaggingClassifier(rfecv_rf)
rfecv_rfBag.fit(X_train,y_train) 

print("Optimal number of features : %d" % rfecv_rfBag.n_features_)
# Out:
# Optimal number of features : 46
# C:\Users\test\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
randomForestBag = BaggingClassifier(randomForest)
randomForestBag.fit(X_train,y_train)

print("Optimal number of features : %d" % randomForestBag.n_features_)
# Out:
# Optimal number of features : 46
# C:\Users\test\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

y_pred = randomForest.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[757 413]
#  [406 755]]
# 0.6486486486486487

# %%
y_pred = rfecv_rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[757 413]
#  [406 755]]
# 0.6486486486486487

# %%
y_pred = rfecv_rfBag.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[759 411]
#  [395 766]]
# 0.6542256542256543

# %%
y_pred = randomForestBag.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[782 388]
#  [408 753]]
# 0.6585156585156585

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

RocCurveDisplay.from_estimator(randomForest, X_test, y_test)

# %%
RocCurveDisplay.from_estimator(rfecv_rf, X_test, y_test)

# %%
RocCurveDisplay.from_estimator(rfecv_rfBag, X_test, y_test)

# %%
RocCurveDisplay.from_estimator(randomForestBag, X_test, y_test)

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (accuracy)")
plt.plot(
    range(1, len(rfecv_rf.grid_scores_) + 1),
    rfecv_rf.grid_scores_,
)
plt.show()
# Out:
# C:\Users\test\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)

# %%
total = rfecv_rfBag.estimators_[0].grid_scores_
for i in range(1,len(rfecv_rfBag.estimators_)):
    total = total + rfecv_rfBag.estimators_[i].grid_scores_

rfecv_rfBag_grid = total/len(rfecv_rfBag.estimators_)

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (accuracy)")
plt.plot(
    range(1, len(rfecv_rfBag_grid) + 1),
    rfecv_rfBag_grid,
)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

import tensorflow as tf
tf.random.set_seed(99)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss = tf.keras.losses.binary_crossentropy,
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.TruePositives(name='tp'),
        tf.keras.metrics.TrueNegatives(name='tn')
    ]
)

# %%
history = model.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 292/292 [==============================] - 1s 1ms/step - loss: 0.6529 - accuracy: 0.6110 - precision: 0.6125 - recall: 0.6061 - tp: 2828.0000 - tn: 2868.0000
# Epoch 2/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.6212 - accuracy: 0.6491 - precision: 0.6509 - recall: 0.6447 - tp: 3008.0000 - tn: 3044.0000
# Epoch 3/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.6080 - accuracy: 0.6590 - precision: 0.6578 - recall: 0.6642 - tp: 3099.0000 - tn: 3045.0000
# Epoch 4/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.5917 - accuracy: 0.6711 - precision: 0.6696 - recall: 0.6768 - tp: 3158.0000 - tn: 3099.0000
# Epoch 5/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.5754 - accuracy: 0.6922 - precision: 0.6934 - recall: 0.6901 - tp: 3220.0000 - tn: 3233.0000
# Epoch 6/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.5562 - accuracy: 0.7019 - precision: 0.7014 - recall: 0.7042 - tp: 3286.0000 - tn: 3258.0000
# Epoch 7/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.5385 - accuracy: 0.7180 - precision: 0.7175 - recall: 0.7201 - tp: 3360.0000 - tn: 3334.0000
# Epoch 8/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.5160 - accuracy: 0.7326 - precision: 0.7320 - recall: 0.7347 - tp: 3428.0000 - tn: 3402.0000
# Epoch 9/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.4924 - accuracy: 0.7550 - precision: 0.7569 - recall: 0.7520 - tp: 3509.0000 - tn: 3530.0000
# Epoch 10/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.4620 - accuracy: 0.7710 - precision: 0.7737 - recall: 0.7666 - tp: 3577.0000 - tn: 3611.0000
# Epoch 11/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.4368 - accuracy: 0.7900 - precision: 0.7918 - recall: 0.7874 - tp: 3674.0000 - tn: 3691.0000
# Epoch 12/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8127 - precision: 0.8157 - recall: 0.8084 - tp: 3772.0000 - tn: 3805.0000
# Epoch 13/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.3657 - accuracy: 0.8284 - precision: 0.8311 - recall: 0.8247 - tp: 3848.0000 - tn: 3875.0000
# Epoch 14/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.3369 - accuracy: 0.8489 - precision: 0.8520 - recall: 0.8448 - tp: 3942.0000 - tn: 3972.0000
# Epoch 15/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.3083 - accuracy: 0.8640 - precision: 0.8646 - recall: 0.8635 - tp: 4029.0000 - tn: 4026.0000
# Epoch 16/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.2784 - accuracy: 0.8808 - precision: 0.8822 - recall: 0.8793 - tp: 4103.0000 - tn: 4109.0000
# Epoch 17/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.2523 - accuracy: 0.8952 - precision: 0.8962 - recall: 0.8941 - tp: 4172.0000 - tn: 4174.0000
# Epoch 18/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.2251 - accuracy: 0.9060 - precision: 0.9084 - recall: 0.9033 - tp: 4215.0000 - tn: 4232.0000
# Epoch 19/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.2001 - accuracy: 0.9188 - precision: 0.9202 - recall: 0.9173 - tp: 4280.0000 - tn: 4286.0000
# Epoch 20/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1856 - accuracy: 0.9246 - precision: 0.9253 - recall: 0.9239 - tp: 4311.0000 - tn: 4309.0000
# Epoch 21/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 0.9392 - precision: 0.9391 - recall: 0.9393 - tp: 4383.0000 - tn: 4373.0000
# Epoch 22/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1608 - accuracy: 0.9380 - precision: 0.9424 - recall: 0.9331 - tp: 4354.0000 - tn: 4391.0000
# Epoch 23/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1357 - accuracy: 0.9483 - precision: 0.9480 - recall: 0.9488 - tp: 4427.0000 - tn: 4414.0000
# Epoch 24/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1195 - accuracy: 0.
100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 0.9878 - precision: 0.9876 - recall: 0.9880 - tp: 4610.0000 - tn: 4599.0000
# Epoch 79/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0217 - accuracy: 0.9923 - precision: 0.9927 - recall: 0.9919 - tp: 4628.0000 - tn: 4623.0000
# Epoch 80/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 0.9939 - precision: 0.9934 - recall: 0.9944 - tp: 4640.0000 - tn: 4626.0000
# Epoch 81/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 0.9942 - precision: 0.9946 - recall: 0.9938 - tp: 4637.0000 - tn: 4632.0000
# Epoch 82/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9929 - precision: 0.9934 - recall: 0.9925 - tp: 4631.0000 - tn: 4626.0000
# Epoch 83/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9903 - precision: 0.9899 - recall: 0.9908 - tp: 4623.0000 - tn: 4610.0000
# Epoch 84/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0676 - accuracy: 0.9773 - precision: 0.9771 - recall: 0.9775 - tp: 4561.0000 - tn: 4550.0000
# Epoch 85/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1058 - accuracy: 0.9633 - precision: 0.9649 - recall: 0.9616 - tp: 4487.0000 - tn: 4494.0000
# Epoch 86/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9871 - precision: 0.9873 - recall: 0.9869 - tp: 4605.0000 - tn: 4598.0000
# Epoch 87/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - tp: 4637.0000 - tn: 4628.0000
# Epoch 88/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 0.9942 - precision: 0.9942 - recall: 0.9942 - tp: 4639.0000 - tn: 4630.0000
# Epoch 89/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 0.9947 - precision: 0.9961 - recall: 0.9934 - tp: 4635.0000 - tn: 4639.0000
# Epoch 90/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0181 - accuracy: 0.9939 - precision: 0.9940 - recall: 0.9938 - tp: 4637.0000 - tn: 4629.0000
# Epoch 91/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0377 - accuracy: 0.9882 - precision: 0.9884 - recall: 0.9880 - tp: 4610.0000 - tn: 4603.0000
# Epoch 92/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1012 - accuracy: 0.9624 - precision: 0.9613 - recall: 0.9636 - tp: 4496.0000 - tn: 4476.0000
# Epoch 93/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0673 - accuracy: 0.9750 - precision: 0.9755 - recall: 0.9745 - tp: 4547.0000 - tn: 4543.0000
# Epoch 94/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0381 - accuracy: 0.9871 - precision: 0.9876 - recall: 0.9867 - tp: 4604.0000 - tn: 4599.0000
# Epoch 95/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 0.9908 - precision: 0.9908 - recall: 0.9908 - tp: 4623.0000 - tn: 4614.0000
# Epoch 96/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 0.9943 - precision: 0.9944 - recall: 0.9942 - tp: 4639.0000 - tn: 4631.0000
# Epoch 97/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 0.9946 - precision: 0.9946 - recall: 0.9946 - tp: 4641.0000 - tn: 4632.0000
# Epoch 98/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.9943 - precision: 0.9940 - recall: 0.9946 - tp: 4641.0000 - tn: 4629.0000
# Epoch 99/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 0.9946 - precision: 0.9936 - recall: 0.9957 - tp: 4646.0000 - tn: 4627.0000
# Epoch 100/100
# 292/292 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 0.9944 - precision: 0.9949 - recall: 0.9940 - tp: 4638.0000 - tn: 4633.0000

# %%
pred = model.predict(X_test_scaled)
pred_classes = [1 if val > 0.5 else 0 for val in np.ravel(pred)]
# Out:
# 73/73 [==============================] - 0s 553us/step

# %%
print(confusion_matrix(y_test, pred_classes))
# Out:
# [[700 470]
#  [463 698]]

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, threshold = roc_curve(y_test, pred)
roc_auc = auc(fpr, tpr)
RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc).plot()

# %%
X_value_scaled = scaler.fit_transform(X_value)

history = model.fit(X_value_scaled, y_values, epochs = 100)
