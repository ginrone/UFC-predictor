# %%
import numpy as np
import pandas as pd

df = pd.read_csv('dataScrapped/allFight.csv')

# %%
for column in df:
    df = df[df[column] != '--']

df['Win'] = 1

dfReversed = df.sample(frac = 1,axis=0)

for index, row in df.iterrows():
    df.loc[index,'A_Fighter'], df.loc[index,'B_Fighter'] = df.loc[index,'B_Fighter'], df.loc[index,'A_Fighter']
    df.loc[index,'A_height'], df.loc[index,'B_height'] = df.loc[index,'B_height'], df.loc[index,'A_height']
    df.loc[index,'A_weight'], df.loc[index,'B_weight'] = df.loc[index,'B_weight'], df.loc[index,'A_weight']
    df.loc[index,'A_range'], df.loc[index,'B_range'] = df.loc[index,'B_range'], df.loc[index,'A_range']
    df.loc[index,'A_Stance'], df.loc[index,'B_Stance'] = df.loc[index,'B_Stance'], df.loc[index,'A_Stance']
    df.loc[index,'A_YearBirth'], df.loc[index,'B_YearBirth'] = df.loc[index,'B_YearBirth'], df.loc[index,'A_YearBirth']
    df.loc[index,'A_SigStrikeLanded'], df.loc[index,'B_SigStrikeLanded'] = df.loc[index,'B_SigStrikeLanded'], df.loc[index,'A_SigStrikeLanded']
    df.loc[index,'A_SigStrikeAcc'], df.loc[index,'B_SigStrikeAcc'] = df.loc[index,'B_SigStrikeAcc'], df.loc[index,'A_SigStrikeAcc']
    df.loc[index,'A_SigStrikeAbsorb'], df.loc[index,'B_SigStrikeAbsorb'] = df.loc[index,'B_SigStrikeAbsorb'], df.loc[index,'A_SigStrikeAbsorb']
    df.loc[index,'A_SigStrikeDef'], df.loc[index,'B_SigStrikeDef'] = df.loc[index,'B_SigStrikeDef'], df.loc[index,'A_SigStrikeDef']
    df.loc[index,'A_TakedownAvg'], df.loc[index,'B_TakedownAvg'] = df.loc[index,'B_TakedownAvg'], df.loc[index,'A_TakedownAvg']
    df.loc[index,'A_TakedownAcc'], df.loc[index,'B_TakedownAcc'] = df.loc[index,'B_TakedownAcc'], df.loc[index,'A_TakedownAcc']
    df.loc[index,'A_TakedownDef'], df.loc[index,'B_TakedownDef'] = df.loc[index,'B_TakedownDef'], df.loc[index,'A_TakedownDef']
    df.loc[index,'A_SubAvg'], df.loc[index,'B_SubAvg'] = df.loc[index,'B_SubAvg'], df.loc[index,'A_SubAvg']
    df.loc[index,'Win'] = 0
    
df = pd.concat([df,dfReversed]).sample(frac = 1)

# %%
df.head(10)
# Out:
#                       A_Fighter                  B_Fighter  \
# 210                Chris Curtis             Rodolfo Vieira
# 533       Olivier Aubin-Mercier                 Drew Dober
# 2477               Dustin Pague                Chico Camus
# 3758                  Jon Fitch               Akihiro Gono
# 2440             Danny Castillo            Michael Johnson
# 5082             Megan Anderson               Amanda Nunes
# 3392         Benoit Saint Denis  Elizeu Zaleski dos Santos
# 883   Elizeu Zaleski dos Santos             Omari Akhmedov
# 797               Vicente Luque     Alvaro Herrera Mendoza
# 2349            Daniel Sarafian                CB Dollaway
#
#                    Division   WinBy  EventYear EventLocation A_height  \
# 210            Middleweight   U-DEC     2022.0      LasVegas     70.0
# 533             Lightweight     SUB     2016.0       Toronto     69.0
# 2477           Bantamweight   U-DEC     2012.0        Denver     69.0
# 3758           Welterweight   U-DEC     2009.0      LasVegas     72.0
# 2440            Lightweight  KO/TKO     2012.0   Minneapolis     69.0
# 5082  Women's Featherweight     SUB     2021.0      LasVegas     72.0
# 3392           Welterweight   U-DEC     2021.0      AbuDhabi     71.0
# 883            Welterweight  KO/TKO     2016.0         Tampa     71.0
# 797            Welterweight     SUB     2016.0      LasVegas     71.0
# 2349           Middleweight   S-DEC     2013.0      SaoPaulo     69.0
#
#      A_weight A_range  A_Stance  ... B_YearBirth  B_SigStrikeLanded  \
# 210     185.0    75.0  Orthodox  ...      1989.0               3.62
# 533     155.0    70.0  Southpaw  ...      1988.0               4.47
# 2477    135.0    74.0  Orthodox  ...      1985.0               2.58
# 3758    170.0    74.0  Orthodox  ...      1974.0               2.18
# 2440    155.0    71.0  Orthodox  ...      1986.0               4.20
# 5082    145.0    72.0  Orthodox  ...      1988.0               4.40
# 3392    155.0    73.0  Southpaw  ...      1986.0               4.65
# 883     170.0    73.0  Orthodox  ...      1987.0               2.97
# 797     170.0    76.0  Orthodox  ...      1990.0               1.89
# 2349    185.0    73.0  Orthodox  ...      1983.0               2.65
#
#       B_SigStrikeAcc  B_SigStrikeAbsorb  B_SigStrikeDef  B_TakedownAvg  \
# 210             54.0               5.09            49.0           3.90
# 533             40.0               4.16            51.0           0.75
# 2477            41.0               2.46            64.0           0.77
# 3758            48.0               2.67            63.0           1.01
# 2440            38.0               3.91            58.0           0.50
# 5082            51.0               2.75            55.0           2.61
# 3392            42.0               3.22            58.0           0.52
# 883             34.0               2.84            55.0           2.58
# 797             38.0               3.40            55.0           0.00
# 2349            47.0               2.58            54.0           3.55
#
#       B_TakedownAcc  B_TakedownDef  B_SubAvg Win
# 210            27.0          100.0       1.0   1
# 533            17.0           54.0       0.1   1
# 2477           40.0           72.0       0.4   0
# 3758           84.0           46.0       0.5   1
# 2440           43.0           79.0       0.1   0
# 5082           56.0           82.0       0.8   0
# 3392           15.0           62.0       0.4   0
# 883            45.0           65.0       0.2   1
# 797             0.0           33.0       1.1   1
# 2349           54.0           62.0       1.2   0
#
# [10 rows x 33 columns]

# %%
dumDivision = pd.get_dummies(df['Division'],prefix='Div_')
df = pd.concat([df, dumDivision], axis='columns')

# dumWinBy = pd.get_dummies(df['WinBy'],prefix='By_')
# df = pd.concat([df, dumWinBy], axis='columns')

# dumYear = pd.get_dummies(df['EventYear'],prefix='Year_')
# df = pd.concat([df, dumYear], axis='columns')

# dumLocation = pd.get_dummies(df['EventLocation'],prefix='Loc_')
# df = pd.concat([df, dumLocation], axis='columns')

dumAStance = pd.get_dummies(df['A_Stance'],prefix='A_')
df = pd.concat([df, dumAStance], axis='columns')

dumBStance = pd.get_dummies(df['B_Stance'],prefix='B_')
df = pd.concat([df, dumBStance], axis='columns')

# %%
df.head()
# Out:
#                   A_Fighter        B_Fighter      Division   WinBy  EventYear  \
# 210            Chris Curtis   Rodolfo Vieira  Middleweight   U-DEC     2022.0
# 533   Olivier Aubin-Mercier       Drew Dober   Lightweight     SUB     2016.0
# 2477           Dustin Pague      Chico Camus  Bantamweight   U-DEC     2012.0
# 3758              Jon Fitch     Akihiro Gono  Welterweight   U-DEC     2009.0
# 2440         Danny Castillo  Michael Johnson   Lightweight  KO/TKO     2012.0
#
#      EventLocation A_height A_weight A_range  A_Stance  ... Loc__Winnipeg  \
# 210       LasVegas     70.0    185.0    75.0  Orthodox  ...             0
# 533        Toronto     69.0    155.0    70.0  Southpaw  ...             0
# 2477        Denver     69.0    135.0    74.0  Orthodox  ...             0
# 3758      LasVegas     72.0    170.0    74.0  Orthodox  ...             0
# 2440   Minneapolis     69.0    155.0    71.0  Orthodox  ...             0
#
#       Loc__Zagreb  A__OpenStance  A__Orthodox  A__Southpaw  A__Switch  \
# 210             0              0            1            0          0
# 533             0              0            0            1          0
# 2477            0              0            1            0          0
# 3758            0              0            1            0          0
# 2440            0              0            1            0          0
#
#       B__OpenStance  B__Orthodox  B__Southpaw B__Switch
# 210               0            1            0         0
# 533               0            0            1         0
# 2477              0            1            0         0
# 3758              0            0            0         1
# 2440              0            0            1         0
#
# [5 rows x 233 columns]

# %%
df['Win'].value_counts()
# Out:
# 1    5827
# 0    5827
# Name: Win, dtype: int64

# %%
pct_win = df['Win'].value_counts()/len(df)
pct_win.plot(kind='pie',autopct='%1.1f%%', rot=0)
# Out:
# <AxesSubplot:ylabel='Win'>

# %%
from sklearn.model_selection import train_test_split

X_values = df.drop(['A_Fighter','B_Fighter','Division','WinBy','EventLocation','A_Stance','B_Stance','Win'],axis=1)
y_values = df['Win']

X_train, X_test, y_train, y_test = train_test_split(X_values, y_values, test_size=0.2, random_state=99)

X_values
# Out:
#      A_height A_weight A_range A_YearBirth  A_SigStrikeLanded  A_SigStrikeAcc  \
# 210      70.0    185.0    75.0      1987.0               6.00            58.0
# 533      69.0    155.0    70.0      1989.0               2.48            51.0
# 2477     69.0    135.0    74.0      1987.0               1.65            53.0
# 3758     72.0    170.0    74.0      1978.0               2.61            50.0
# 2440     69.0    155.0    71.0      1979.0               2.57            42.0
# ...       ...      ...     ...         ...                ...             ...
# 6071     72.0    155.0    71.0      1988.0               3.76            42.0
# 6545     63.0    115.0    64.0      1985.0               5.36            48.0
# 5963     66.0    145.0    71.0      1988.0               6.79            57.0
# 5866     72.0    145.0    75.0      1990.0               4.83            47.0
# 2392     72.0    170.0    76.0      1985.0               4.57            45.0
#
#       A_SigStrikeAbsorb  A_SigStrikeDef  A_TakedownAvg  A_TakedownAcc  ...  \
# 210                6.39            52.0           0.00            0.0  ...
# 533                2.97            55.0           2.36           33.0  ...
# 2477               2.96            41.0           1.03           44.0  ...
# 3758               1.65            54.0           3.60           51.0  ...
# 2440               1.96            62.0           2.95           38.0  ...
# ...                 ...             ...            ...            ...  ...
# 6071               3.07            60.0           0.92           28.0  ...
# 6545               4.98            62.0           0.61           29.0  ...
# 5963               3.53            60.0           1.71           36.0  ...
# 5866               4.61            51.0           0.85           36.0  ...
# 2392               3.77            52.0           1.05           30.0  ...
#
#       Loc__Winnipeg  Loc__Zagreb A__OpenStance A__Orthodox A__Southpaw  \
# 210               0            0             0           1           0
# 533               0            0             0           0           1
# 2477              0            0             0           1           0
# 3758              0            0             0           1           0
# 2440              0            0             0           1           0
# ...             ...          ...           ...         ...         ...
# 6071              0            0             0           0           1
# 6545              0            0             0           1           0
# 5963              0            0             0           1           0
# 5866              0            0             0           0           0
# 2392              0            0             0           0           1
#
#      A__Switch  B__OpenStance  B__Orthodox  B__Southpaw  B__Switch
# 210          0              0            1            0          0
# 533          0              0            0            1          0
# 2477         0              0            1            0          0
# 3758         0              0            0            0          1
# 2440         0              0            0            1          0
# ...        ...            ...          ...          ...        ...
# 6071         0              0            0            1          0
# 6545         0              0            1            0          0
# 5963         0              0            1            0          0
# 5866         1              0            1            0          0
# 2392         0              0            0            1          0
#
# [11654 rows x 224 columns]

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier

randomForest = RandomForestClassifier(random_state=99)
randomForest.fit(X_train,y_train) 

print("Optimal number of features : %d" % randomForest.n_features_)
# Out:
# Optimal number of features : 224
# C:\Users\test\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.feature_selection import RFECV

rfecv_rf = RFECV(estimator=randomForest,cv=5)
rfecv_rf.fit(X_train,y_train) 

print("Optimal number of features : %d" % rfecv_rf.n_features_)
# Out:
# Optimal number of features : 58

# %%
from sklearn.ensemble import BaggingClassifier

rfecv_rfBag = BaggingClassifier(rfecv_rf)
rfecv_rfBag.fit(X_train,y_train) 

print("Optimal number of features : %d" % rfecv_rfBag.n_features_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       1 from sklearn.ensemble import BaggingClassifier
#       3 rfecv_rfBag = BaggingClassifier(rfecv_rf)
# ----> 4 rfecv_rfBag.fit(X_train,y_train)
#       6 print("Optimal number of features : %d" % rfecv_rfBag.n_features_)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_bagging.py:297, in BaseBagging.fit(self, X, y, sample_weight)
#     288 # Convert data (X is required to be 2d and indexable)
#     289 X, y = self._validate_data(
#     290     X,
#     291     y,
#    (...)
#     295     multi_output=True,
#     296 )
# --> 297 return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_bagging.py:434, in BaseBagging._fit(self, X, y, max_samples, max_depth, sample_weight, check_input)
#     431 seeds = random_state.randint(MAX_INT, size=n_more_estimators)
#     432 self._seeds = seeds
# --> 434 all_results = Parallel(
#     435     n_jobs=n_jobs, verbose=self.verbose, **self._parallel_args()
#     436 )(
#     437     delayed(_parallel_build_estimators)(
#     438         n_estimators[i],
#     439         self,
#     440         X,
#     441         y,
#     442         sample_weight,
#     443         seeds[starts[i] : starts[i + 1]],
#     444         total_n_estimators,
#     445         verbose=self.verbose,
#     446         check_input=check_input,
#     447     )
#     448     for i in range(n_jobs)
#     449 )
#     451 # Reduce
#     452 self.estimators_ += list(
#     453     itertools.chain.from_iterable(t[0] for t in all_results)
#     454 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_bagging.py:141, in _parallel_build_estimators(n_estimators, ensemble, X, y, sample_weight, seeds, total_n_estimators, verbose, check_input)
#     138     estimator_fit(X[:, features], y, sample_weight=curr_sample_weight)
#     140 else:
# --> 141     estimator_fit(X[indices][:, features], y[indices])
#     143 estimators.append(estimator)
#     144 estimators_features.append(features)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_rfe.py:723, in RFECV.fit(self, X, y, groups)
#     720     parallel = Parallel(n_jobs=self.n_jobs)
#     721     func = delayed(_rfe_single_fit)
# --> 723 scores = parallel(
#     724     func(rfe, self.estimator, X, y, train, test, scorer)
#     725     for train, test in cv.split(X, y, groups)
#     726 )
#     728 scores = np.array(scores)
#     729 scores_sum = np.sum(scores, axis=0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_rfe.py:724, in <genexpr>(.0)
#     720     parallel = Parallel(n_jobs=self.n_jobs)
#     721     func = delayed(_rfe_single_fit)
#     723 scores = parallel(
# --> 724     func(rfe, self.estimator, X, y, train, test, scorer)
#     725     for train, test in cv.split(X, y, groups)
#     726 )
#     728 scores = np.array(scores)
#     729 scores_sum = np.sum(scores, axis=0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_rfe.py:37, in _rfe_single_fit(rfe, estimator, X, y, train, test, scorer)
#      35 X_train, y_train = _safe_split(estimator, X, y, train)
#      36 X_test, y_test = _safe_split(estimator, X, y, test, train)
# ---> 37 return rfe._fit(
#      38     X_train,
#      39     y_train,
#      40     lambda estimator, features: _score(
#      41         estimator, X_test[:, features], y_test, scorer
#      42     ),
#      43 ).scores_
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_rfe.py:296, in RFE._fit(self, X, y, step_score, **fit_params)
#     293 if self.verbose > 0:
#     294     print("Fitting estimator with %d features." % np.sum(support_))
# --> 296 estimator.fit(X[:, features], y, **fit_params)
#     298 # Get importance and rank them
#     299 importances = _get_feature_importances(
#     300     estimator,
#     301     self.importance_getter,
#     302     transform_func="square",
#     303 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190 else:
#     191     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
randomForestBag = BaggingClassifier(randomForest)
randomForestBag.fit(X_train,y_train)

print("Optimal number of features : %d" % randomForestBag.n_features_)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

y_pred = randomForest.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[726 435]
#  [428 742]]
# 0.6297726297726298

# %%
y_pred = rfecv_rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[728 433]
#  [431 739]]
# 0.6293436293436293

# %%
y_pred = rfecv_rfBag.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))

# %%
y_pred = randomForestBag.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

RocCurveDisplay.from_estimator(randomForest, X_test, y_test)

# %%
RocCurveDisplay.from_estimator(rfecv_rf, X_test, y_test)

# %%
RocCurveDisplay.from_estimator(rfecv_rfBag, X_test, y_test)

# %%
RocCurveDisplay.from_estimator(randomForestBag, X_test, y_test)

# %%
# for i in range(len(rfecv_rf.ranking_)):
#     print(df.columns[i],rfecv_rf.ranking_[i])

# for i in range(len(rfecv_rfBag.estimators_)):
#     for j in range(len(rfecv_rfBag.estimators_[i].ranking_)):
#         print(df.columns[j],rfecv_rfBag.estimators_[i].ranking_[j])

print(randomForest.feature_importances_)

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (accuracy)")
plt.plot(
    range(1, len(rfecv_rf.grid_scores_) + 1),
    rfecv_rf.grid_scores_,
)
plt.show()

# %%
total = rfecv_rfBag.estimators_[0].grid_scores_
for i in range(1,len(rfecv_rfBag.estimators_)):
    total = total + rfecv_rfBag.estimators_[i].grid_scores_

rfecv_rfBag_grid = total/len(rfecv_rfBag.estimators_)

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (accuracy)")
plt.plot(
    range(1, len(rfecv_rfBag_grid) + 1),
    rfecv_rfBag_grid,
)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

import tensorflow as tf
tf.random.set_seed(99)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss = tf.keras.losses.binary_crossentropy,
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.TruePositives(name='tp'),
        tf.keras.metrics.TrueNegatives(name='tn')
    ]
)

# %%
history = model.fit(X_train_scaled, y_train, epochs = 100)

# %%
pred = model.predict(X_test_scaled)
pred_classes = [1 if val > 0.5 else 0 for val in np.ravel(pred)]

# %%
print(confusion_matrix(y_test, pred_classes))

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, threshold = roc_curve(y_test, pred)
roc_auc = auc(fpr, tpr)
RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc).plot()
